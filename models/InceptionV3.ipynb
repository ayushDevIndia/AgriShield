# %%
# ============================================================
# InceptionV3 + CBAM | Corn Weed Dataset (5 Classes)
# TF 2.17+ | Keras 3.x | COLAB | SINGLE RUN | PAPER-READY
# ============================================================

# -------------------- DRIVE --------------------
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# -------------------- IMPORTS --------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import seaborn as sns

# -------------------- SEED --------------------
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# -------------------- CONFIG --------------------
IMG_SIZE = 224   # NOTE: Inception prefers 299, but 224 works fine
BATCH_SIZE = 32
EPOCHS = 25
NUM_CLASSES = 5

DATASET_PATH = "/content/drive/MyDrive/corn weed datasets"

CLASS_NAMES = [
    'bluegrass',
    'chenopodium album',
    'cirsium setosum',
    'corn',
    'sedge'
]

# -------------------- DATA --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(AUTOTUNE)
val_ds   = val_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(AUTOTUNE)

# ============================================================
# CBAM BLOCK
# ============================================================
def cbam_block(x, ratio=8):
    ch = x.shape[-1]

    # Channel Attention
    avg = layers.GlobalAveragePooling2D()(x)
    maxp = layers.GlobalMaxPooling2D()(x)

    shared = layers.Dense(ch // ratio, activation='relu')
    dense = layers.Dense(ch)

    ca = layers.Activation('sigmoid')(
        dense(shared(avg)) + dense(shared(maxp))
    )
    ca = layers.Reshape((1, 1, ch))(ca)
    x = layers.Multiply()([x, ca])

    # Spatial Attention
    avg_sp = layers.Lambda(lambda t: tf.reduce_mean(t, axis=-1, keepdims=True))(x)
    max_sp = layers.Lambda(lambda t: tf.reduce_max(t, axis=-1, keepdims=True))(x)

    sa = layers.Conv2D(
        1, kernel_size=7, padding='same', activation='sigmoid'
    )(layers.Concatenate()([avg_sp, max_sp]))

    return layers.Multiply()([x, sa])

# ============================================================
# MODEL: INCEPTIONV3 + CBAM
# ============================================================
def build_inception_cbam():
    base_model = InceptionV3(
        weights="imagenet",
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    base_model.trainable = False

    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base_model(inputs)

    # CBAM Attention
    x = cbam_block(x)

    # Classification Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
    return models.Model(inputs, outputs)

model = build_inception_cbam()

# -------------------- COMPILE --------------------
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# -------------------- CALLBACKS --------------------
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=3, factor=0.3)
]

# -------------------- TRAIN --------------------
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# ============================================================
# TRAINING CURVES
# ============================================================
acc      = history.history["accuracy"]
val_acc  = history.history["val_accuracy"]
loss     = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Curve")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# ============================================================
# EVALUATION
# ============================================================
y_true, y_pred = [], []

for x, y in val_ds:
    preds = model.predict(x, verbose=0)
    y_true.extend(np.argmax(y.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

accuracy  = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="weighted")
recall    = recall_score(y_true, y_pred, average="weighted")
f1        = f1_score(y_true, y_pred, average="weighted")

print("\n================ FINAL RESULTS ================")
print(f"Accuracy   : {accuracy*100:.2f}%")
print(f"Precision  : {precision:.4f}")
print(f"Recall     : {recall:.4f}")
print(f"F1-score   : {f1:.4f}")

print("\n============= CLASSIFICATION REPORT ============")
print(classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    digits=4
))

# -------------------- CONFUSION MATRIX --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Found 5609 files belonging to 5 classes.
# Using 4488 files for training.
# Found 5609 files belonging to 5 classes.
# Using 1121 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_v3        │ (None, 5, 5,      │ 21,802,784 │ input_layer_1[0]… │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ inception_v3[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 2048)      │          0 │ inception_v3[0][… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2048)      │    526,336 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 2048)      │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_94       │ (None, 2048)      │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1,      │          0 │ activation_94[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 5, 5,      │          0 │ inception_v3[0][… │
# │                     │ 2048)             │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 5, 5, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 5, 5, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 5, 5, 2)   │          0 │ lambda[0][0],     │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 5, 5, 1)   │         99 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 5, 5,      │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 2048)             │            │ conv2d_94[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ multiply_1[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,379,592 (89.19 MB)
#  Trainable params: 1,576,808 (6.02 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)
# Epoch 1/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 709s 5s/step - accuracy: 0.7522 - loss: 0.7095 - val_accuracy: 0.9019 - val_loss: 0.3275 - learning_rate: 1.0000e-04
# Epoch 2/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - accuracy: 0.8917 - loss: 0.3318 - val_accuracy: 0.9197 - val_loss: 0.2394 - learning_rate: 1.0000e-04
# Epoch 3/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - accuracy: 0.9138 - loss: 0.2491 - val_accuracy: 0.9188 - val_loss: 0.2244 - learning_rate: 1.0000e-04
# Epoch 4/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9309 - loss: 0.1941 - val_accuracy: 0.9411 - val_loss: 0.1720 - learning_rate: 1.0000e-04
# Epoch 5/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - accuracy: 0.9485 - loss: 0.1604 - val_accuracy: 0.9411 - val_loss: 0.1688 - learning_rate: 1.0000e-04
# Epoch 6/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - accuracy: 0.9579 - loss: 0.1296 - val_accuracy: 0.9500 - val_loss: 0.1431 - learning_rate: 1.0000e-04
# Epoch 7/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - accuracy: 0.9641 - loss: 0.1081 - val_accuracy: 0.9509 - val_loss: 0.1401 - learning_rate: 1.0000e-04
# Epoch 8/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - accuracy: 0.9708 - loss: 0.0867 - val_accuracy: 0.9563 - val_loss: 0.1289 - learning_rate: 1.0000e-04
# Epoch 9/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - accuracy: 0.9784 - loss: 0.0682 - val_accuracy: 0.9527 - val_loss: 0.1366 - learning_rate: 1.0000e-04
# Epoch 10/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9840 - loss: 0.0596 - val_accuracy: 0.9572 - val_loss: 0.1316 - learning_rate: 1.0000e-04
# Epoch 11/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - accuracy: 0.9860 - loss: 0.0484 - val_accuracy: 0.9581 - val_loss: 0.1314 - learning_rate: 1.0000e-04
# Epoch 12/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 294ms/step - accuracy: 0.9926 - loss: 0.0315 - val_accuracy: 0.9625 - val_loss: 0.1152 - learning_rate: 3.0000e-05
# Epoch 13/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9953 - loss: 0.0254 - val_accuracy: 0.9590 - val_loss: 0.1125 - learning_rate: 3.0000e-05
# Epoch 14/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9958 - loss: 0.0231 - val_accuracy: 0.9563 - val_loss: 0.1147 - learning_rate: 3.0000e-05
# Epoch 15/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - accuracy: 0.9971 - loss: 0.0213 - val_accuracy: 0.9616 - val_loss: 0.1149 - learning_rate: 3.0000e-05
# Epoch 16/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 80s 297ms/step - accuracy: 0.9975 - loss: 0.0192 - val_accuracy: 0.9590 - val_loss: 0.1170 - learning_rate: 3.0000e-05
# Epoch 17/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - accuracy: 0.9978 - loss: 0.0179 - val_accuracy: 0.9652 - val_loss: 0.1141 - learning_rate: 9.0000e-06
# Epoch 18/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - accuracy: 0.9991 - loss: 0.0160 - val_accuracy: 0.9599 - val_loss: 0.1139 - learning_rate: 9.0000e-06
# ================ FINAL RESULTS ================
# Accuracy   : 95.90%
# Precision  : 0.9589
# Recall     : 0.9590
# F1-score   : 0.9589
#
# ============= CLASSIFICATION REPORT ============
#                    precision    recall  f1-score   support
#
#         bluegrass     0.9367    0.9409    0.9388       220
# chenopodium album     0.9931    0.9863    0.9897       146
#   cirsium setosum     0.9662    0.9923    0.9790       259
#              corn     0.9402    0.9205    0.9302       239
#             sedge     0.9686    0.9611    0.9648       257
#
#          accuracy                         0.9590      1121
#         macro avg     0.9609    0.9602    0.9605      1121
#      weighted avg     0.9589    0.9590    0.9589      1121

# %%
# ============================================================
# SAVE TRAINED DEEP LEARNING MODEL TO DISK
# ============================================================
# This cell exports the fully-trained model and weights as an .h5 file
model.save("InceptionV3.h5")
print("Trained InceptionV3 model successfully saved as InceptionV3.h5!")
