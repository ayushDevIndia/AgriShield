# %%
# ============================================================
# Inception-ResNet-V2 + CBAM | Corn Weed Dataset (5 Classes)
# TF 2.17+ | Keras 3.x | COLAB | SINGLE RUN | PAPER-READY
# ============================================================

# -------------------- DRIVE --------------------
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# -------------------- IMPORTS --------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import seaborn as sns

# -------------------- SEED --------------------
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# -------------------- CONFIG --------------------
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 25
NUM_CLASSES = 5

DATASET_PATH = "/content/drive/MyDrive/corn weed datasets"

CLASS_NAMES = [
    'bluegrass',
    'chenopodium album',
    'cirsium setosum',
    'corn',
    'sedge'
]

# -------------------- DATA --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(AUTOTUNE)
val_ds   = val_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(AUTOTUNE)

# ============================================================
# CBAM BLOCK
# ============================================================
def cbam_block(x, ratio=8):
    ch = x.shape[-1]

    # Channel Attention
    avg = layers.GlobalAveragePooling2D()(x)
    maxp = layers.GlobalMaxPooling2D()(x)

    shared = layers.Dense(ch // ratio, activation='relu')
    dense = layers.Dense(ch)

    ca = layers.Activation('sigmoid')(
        dense(shared(avg)) + dense(shared(maxp))
    )
    ca = layers.Reshape((1, 1, ch))(ca)
    x = layers.Multiply()([x, ca])

    # Spatial Attention
    avg_sp = layers.Lambda(lambda t: tf.reduce_mean(t, axis=-1, keepdims=True))(x)
    max_sp = layers.Lambda(lambda t: tf.reduce_max(t, axis=-1, keepdims=True))(x)

    sa = layers.Conv2D(
        1, kernel_size=7, padding='same', activation='sigmoid'
    )(layers.Concatenate()([avg_sp, max_sp]))

    return layers.Multiply()([x, sa])

# ============================================================
# MODEL: INCEPTION-RESNET-V2 + CBAM
# ============================================================
def build_inception_resnet_cbam():
    base_model = InceptionResNetV2(
        weights="imagenet",
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    base_model.trainable = False

    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base_model(inputs)

    # CBAM Attention
    x = cbam_block(x)

    # Classification Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
    return models.Model(inputs, outputs)

model = build_inception_resnet_cbam()

# -------------------- COMPILE --------------------
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# -------------------- CALLBACKS --------------------
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=3, factor=0.3)
]

# -------------------- TRAIN --------------------
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# ============================================================
# TRAINING CURVES
# ============================================================
acc      = history.history["accuracy"]
val_acc  = history.history["val_accuracy"]
loss     = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Curve")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# ============================================================
# EVALUATION
# ============================================================
y_true, y_pred = [], []

for x, y in val_ds:
    preds = model.predict(x, verbose=0)
    y_true.extend(np.argmax(y.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

accuracy  = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="weighted")
recall    = recall_score(y_true, y_pred, average="weighted")
f1        = f1_score(y_true, y_pred, average="weighted")

print("\n================ FINAL RESULTS ================")
print(f"Accuracy   : {accuracy*100:.2f}%")
print(f"Precision  : {precision:.4f}")
print(f"Recall     : {recall:.4f}")
print(f"F1-score   : {f1:.4f}")

print("\n============= CLASSIFICATION REPORT ============")
print(classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    digits=4
))

# -------------------- CONFUSION MATRIX --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Found 5998 files belonging to 5 classes.
# Using 4799 files for training.
# Found 5998 files belonging to 5 classes.
# Using 1199 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_resnet_v2 │ (None, 5, 5,      │ 54,336,736 │ input_layer_1[0]… │
# │ (Functional)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1536)      │          0 │ inception_resnet… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 1536)      │          0 │ inception_resnet… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 192)       │    295,104 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1536)      │    296,448 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1536)      │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_203      │ (None, 1536)      │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1,      │          0 │ activation_203[0… │
# │                     │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 5, 5,      │          0 │ inception_resnet… │
# │                     │ 1536)             │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 5, 5, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 5, 5, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 5, 5, 2)   │          0 │ lambda[0][0],     │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, 5, 5, 1)   │         99 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 5, 5,      │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 1536)             │            │ conv2d_203[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1536)      │          0 │ multiply_1[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    393,472 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 55,323,144 (211.04 MB)
#  Trainable params: 986,408 (3.76 MB)
#  Non-trainable params: 54,336,736 (207.28 MB)
# Epoch 1/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1077s 7s/step - accuracy: 0.5898 - loss: 1.0540 - val_accuracy: 0.8899 - val_loss: 0.3595 - learning_rate: 1.0000e-04
# Epoch 2/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 43s 286ms/step - accuracy: 0.8642 - loss: 0.4100 - val_accuracy: 0.9191 - val_loss: 0.2727 - learning_rate: 1.0000e-04
# Epoch 3/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 43s 284ms/step - accuracy: 0.8989 - loss: 0.3080 - val_accuracy: 0.9291 - val_loss: 0.2179 - learning_rate: 1.0000e-04
# Epoch 4/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 281ms/step - accuracy: 0.9191 - loss: 0.2436 - val_accuracy: 0.9433 - val_loss: 0.1943 - learning_rate: 1.0000e-04
# Epoch 5/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 279ms/step - accuracy: 0.9209 - loss: 0.2224 - val_accuracy: 0.9475 - val_loss: 0.1714 - learning_rate: 1.0000e-04
# Epoch 6/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 282ms/step - accuracy: 0.9398 - loss: 0.1935 - val_accuracy: 0.9441 - val_loss: 0.1651 - learning_rate: 1.0000e-04
# Epoch 7/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 277ms/step - accuracy: 0.9492 - loss: 0.1611 - val_accuracy: 0.9525 - val_loss: 0.1418 - learning_rate: 1.0000e-04
# Epoch 8/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - accuracy: 0.9534 - loss: 0.1373 - val_accuracy: 0.9458 - val_loss: 0.1744 - learning_rate: 1.0000e-04
# Epoch 9/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 277ms/step - accuracy: 0.9590 - loss: 0.1308 - val_accuracy: 0.9491 - val_loss: 0.1501 - learning_rate: 1.0000e-04
# Epoch 10/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - accuracy: 0.9652 - loss: 0.1077 - val_accuracy: 0.9575 - val_loss: 0.1420 - learning_rate: 1.0000e-04
# Epoch 11/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 82s 277ms/step - accuracy: 0.9729 - loss: 0.0882 - val_accuracy: 0.9591 - val_loss: 0.1291 - learning_rate: 3.0000e-05
# Epoch 12/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 82s 277ms/step - accuracy: 0.9748 - loss: 0.0814 - val_accuracy: 0.9591 - val_loss: 0.1283 - learning_rate: 3.0000e-05
# Epoch 13/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 44s 293ms/step - accuracy: 0.9787 - loss: 0.0748 - val_accuracy: 0.9608 - val_loss: 0.1376 - learning_rate: 3.0000e-05
# Epoch 14/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - accuracy: 0.9764 - loss: 0.0762 - val_accuracy: 0.9616 - val_loss: 0.1323 - learning_rate: 3.0000e-05
# Epoch 15/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - accuracy: 0.9836 - loss: 0.0662 - val_accuracy: 0.9550 - val_loss: 0.1345 - learning_rate: 3.0000e-05
# Epoch 16/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 82s 275ms/step - accuracy: 0.9856 - loss: 0.0626 - val_accuracy: 0.9616 - val_loss: 0.1247 - learning_rate: 9.0000e-06
# Epoch 17/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - accuracy: 0.9837 - loss: 0.0623 - val_accuracy: 0.9625 - val_loss: 0.1233 - learning_rate: 9.0000e-06
# Epoch 18/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 273ms/step - accuracy: 0.9812 - loss: 0.0654 - val_accuracy: 0.9633 - val_loss: 0.1240 - learning_rate: 9.0000e-06
# Epoch 19/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 278ms/step - accuracy: 0.9855 - loss: 0.0592 - val_accuracy: 0.9608 - val_loss: 0.1229 - learning_rate: 9.0000e-06
# Epoch 20/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 277ms/step - accuracy: 0.9843 - loss: 0.0591 - val_accuracy: 0.9608 - val_loss: 0.1224 - learning_rate: 9.0000e-06
# Epoch 21/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - accuracy: 0.9869 - loss: 0.0535 - val_accuracy: 0.9616 - val_loss: 0.1215 - learning_rate: 9.0000e-06
# Epoch 22/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - accuracy: 0.9857 - loss: 0.0537 - val_accuracy: 0.9591 - val_loss: 0.1228 - learning_rate: 9.0000e-06
# Epoch 23/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 273ms/step - accuracy: 0.9880 - loss: 0.0516 - val_accuracy: 0.9600 - val_loss: 0.1235 - learning_rate: 9.0000e-06
# Epoch 24/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 277ms/step - accuracy: 0.9845 - loss: 0.0534 - val_accuracy: 0.9608 - val_loss: 0.1216 - learning_rate: 9.0000e-06
# Epoch 25/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 44s 293ms/step - accuracy: 0.9872 - loss: 0.0511 - val_accuracy: 0.9608 - val_loss: 0.1200 - learning_rate: 2.7000e-06
# ================ FINAL RESULTS ================
# Accuracy   : 96.08%
# Precision  : 0.9610
# Recall     : 0.9608
# F1-score   : 0.9609
#
# ============= CLASSIFICATION REPORT ============
#                    precision    recall  f1-score   support
#
#         bluegrass     0.9375    0.9545    0.9459       220
# chenopodium album     0.9869    0.9869    0.9869       229
#   cirsium setosum     0.9739    0.9596    0.9667       272
#              corn     0.9292    0.9333    0.9313       225
#             sedge     0.9722    0.9684    0.9703       253
#
#          accuracy                         0.9608      1199
#         macro avg     0.9599    0.9605    0.9602      1199
#      weighted avg     0.9610    0.9608    0.9609      1199

# %%
# ============================================================
# SAVE TRAINED DEEP LEARNING MODEL TO DISK
# ============================================================
# This cell exports the fully-trained model and weights as an .h5 file
model.save("Inception_ResNet_v2.h5")
print("Trained Inception-ResNet-v2 model successfully saved as Inception_ResNet_v2.h5!")
